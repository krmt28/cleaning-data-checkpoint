# %% [markdown]
# # Checkpoint Three: Cleaning Data
#
# Now you are ready to clean your data. Before starting coding, provide the link to your dataset below.
#
# My dataset: https://www.kaggle.com/datasets/prasertk/cities-with-the-best-worklife-balance-2022
#
# Import the necessary libraries and create your dataframe(s).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df= pd.read_csv("Cities with the Best Work-Life Balance 2022.csv")

# Did creating the dataframe work?
df
# Out:
#     2022 2021          City       Country Remote Jobs Overworked Population  \
# 0      1    2          Oslo        Norway      41.72%                11.20%
# 1      2    -          Bern   Switzerland      44.86%                11.40%
# 2      3    1      Helsinki       Finland      38.92%                12.70%
# 3      4    3        Zurich   Switzerland      44.86%                11.90%
# 4      5    5    Copenhagen       Denmark      41.42%                10.50%
# ..   ...  ...           ...           ...         ...                   ...
# 95    96   49       Bangkok      Thailand      16.84%                15.10%
# 96    97   47     Sao Paulo        Brazil      25.65%                11.80%
# 97    98   50  Kuala Lumpur      Malaysia      30.70%                17.10%
# 98    99    -         Dubai           UAE      28.89%                23.40%
# 99   100    -     Cape Town  South Africa      26.06%                14.80%
#
# ...

# %% [markdown]
# ## Missing Data
#
# Test your dataset for missing data and handle it as needed. Make notes in the form of code comments as to your thought process.

# %%
#check for nulls
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# 2022 - 0%
# 2021 - 0%
# City - 0%
# Country - 0%
# Remote Jobs - 0%
# Overworked Population - 0%
# Minimum Vacations Offered (Days) - 0%
# Vacations Taken (Days) - 0%
# Unemployment - 0%
# Multiple Jobholders - 0%
# Inflation - 0%
# Paid Parental Leave (Days) - 0%
# Covid Impact - 0%
# Covid Support - 0%
# Healthcare - 0%
# Access to Mental Healthcare - 0%
# Inclusivity & Tolerance - 0%
# Affordability - 0%
# Happiness, Culture & Leisure - 0%
# City Safety - 0%
# Outdoor Spaces - 0%
# Air Quality - 0%
# Wellness and Fitness - 0%
# TOTAL SCORE - 0%

# %%
# Plot a heatmap of any missing data
cols = df.columns[:52] # first 30 columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colours))
#This confirms data is not missing
# Out:
# <Axes: >

# %% [markdown]
# ## Irregular Data
#
# Detect outliers in your dataset and handle them as needed. Use code comments to make notes about your thought process.

# %%
# Plot a histogram to see if there are any outliers.
df.hist()
# Out:
# array([[<Axes: title={'center': '2022'}>,
#         <Axes: title={'center': 'Minimum Vacations Offered (Days)'}>,
#         <Axes: title={'center': 'Unemployment'}>,
#         <Axes: title={'center': 'Covid Impact'}>],
#        [<Axes: title={'center': 'Covid Support'}>,
#         <Axes: title={'center': 'Healthcare'}>,
#         <Axes: title={'center': 'Access to Mental Healthcare'}>,
#         <Axes: title={'center': 'Inclusivity & Tolerance'}>],
#        [<Axes: title={'center': 'Affordability'}>,
#         <Axes: title={'center': 'Happiness, Culture & Leisure'}>,
#         <Axes: title={'center': 'City Safety'}>,
#         <Axes: title={'center': 'Outdoor Spaces'}>],
#        [<Axes: title={'center': 'Air Quality'}>,
#         <Axes: title={'center': 'Wellness and Fitness'}>,
#         <Axes: title={'center': 'TOTAL SCORE'}>, <Axes: >]], dtype=object)

# %%
#checking covid support more clearly
sns.displot(data=df, x='Covid Support', height = 5, aspect = 3)
#Only one city had a suport rating at 50. Not something I want to edit in this particular dataset but making a note of it.

# %%
# Use the describe() method
df.describe()
# Out:
#              2022  Minimum Vacations Offered (Days)  Unemployment  \
# count  100.000000                        100.000000    100.000000
# mean    50.500000                         14.410000     93.292000
# std     29.011492                          6.313518      5.888556
# min      1.000000                          6.000000     50.000000
# 25%     25.750000                         10.000000     92.675000
# 50%     50.500000                         10.000000     94.850000
# 75%     75.250000                         20.000000     95.950000
# max    100.000000                         30.000000    100.000000
#
#        Covid Impact  Covid Support  Healthcare  Access to Mental Healthcare  \
# count    100.000000      100.00000  100.000000                   100.000000
# mean      77.875000       84.95300   88.753000                    72.143000
# std        6.959949        6.91823    8.483537                     8.688286
# ...

# %%
#City Safety's numbers seemed a bit off - so double checking it with a boxplot
df.boxplot(column=['City Safety'])
#Looks like there are 2 cities that have city safety rating under 20.  Not something I want to edit in this particular dataset but making a note of it.
# Out:
# <Axes: >

# %% [markdown]
# ## Unnecessary Data
#
# Look for the different types of unnecessary data in your dataset and address it as needed. Make sure to use code comments to illustrate your thought process.

# %%
#Check to make sure none of the cities are duplicated - in turn checking for duplicated rows
df['City'].value_counts()
# Out:
# Oslo            1
# Pittsburgh      1
# Tucson          1
# Indianapolis    1
# Philadelphia    1
#                ..
# Manchester      1
# Calgary         1
# Graz            1
# Paris           1
# Cape Town       1
# Name: City, Length: 100, dtype: int64

# %%
#Another way to double check that there are 100 distinct cities listed
df['City'].nunique( )
# Out:
# 100

# %%
#Check columns for relevance and possible duplication of columns
df.info()

#There looks to be no columns that have the same name.  Also because there is a total score column - I would not want to remove any columns that could impact that number.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   2022                              100 non-null    int64
#  1   2021                              100 non-null    object
#  2   City                              100 non-null    object
#  3   Country                           100 non-null    object
#  4   Remote Jobs                       100 non-null    object
#  5   Overworked Population             100 non-null    object
#  6   Minimum Vacations Offered (Days)  100 non-null    int64
#  7   Vacations Taken (Days)            100 non-null    object
#  8   Unemployment                      100 non-null    float64
#  9   Multiple Jobholders               100 non-null    object
#  10  Inflation                         100 non-null    object
# ...

# %% [markdown]
# ## Inconsistent Data
#
# Check for inconsistent data and address any that arises. As always, use code comments to illustrate your thought process.

# %%
#Most of the data set is numerical ratings 
#Look for inconsistant use of capitalization, spelling and duplicated countries
df['Country'].value_counts()
# Out:
# USA             51
# Germany          9
# UK               4
# Canada           4
# Switzerland      3
# Spain            2
# Australia        2
# Austria          2
# Norway           1
# South Korea      1
# Hong Kong        1
# Argentina        1
# Uruguay          1
# Hungary          1
# Thailand         1
# Brazil           1
# Malaysia         1
# UAE              1
# Italy            1
# Ireland          1
# Portugal         1
# Singapore        1
# Belgium          1
# France           1
# New Zealand      1
# Japan            1
# Netherlands      1
# Sweden           1
# Denmark          1
# Finland          1
# South Africa     1
# Name: Country, dtype: int64

# %%
#Due to my data set being so clean - I have not had to make any updates.

# %% [markdown]
# ## Summarize Your Results
#
# Make note of your answers to the following questions.
#
# 1. Did you find all four types of dirty data in your dataset? No, I found what could be considered outliers if the data was set up differently.  But overall my data set was very clean.
# 2. Did the process of cleaning your data give you new insights into your dataset? Yes, I would not have thought a city with low city safety could have made the list.
# 3. Is there anything you would like to make note of when it comes to manipulating the data and making visualizations? I am even more interested into looking into covid support and covid impact in relation to the top cities. I am also suprised by some of the vacation numbers and would like to see about comparing vacation days offered and taken.
